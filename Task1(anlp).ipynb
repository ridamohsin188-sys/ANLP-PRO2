# %%
import os
os.makedirs("/content/emotion-bert", exist_ok=True)
os.chdir("/content/emotion-bert")

# %%
# !pip install google-auth==2.38.0 google-auth-oauthlib==1.0.0 google-auth-httplib2==0.1.0 --force-reinstall
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.5/153.5 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 8.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import pandas as pd
import requests
import json
url = 'https://raw.githubusercontent.com/f258008-art/EmotionDetection/refs/heads/main/kaggle%20(1).json'
response = requests.get(url)
data= response.json()
df = pd.DataFrame(data)
print (df.head())
print (df['emotion'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3651918083.py in <cell line: 0>()
#       5 response = requests.get(url)
#       6 data= response.json()
# ----> 7 df = pd.DataFrame(data)
#       8 print (df.head())
#       9 print (df['emotion'].value_counts())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
import requests
import json

url = 'https://raw.githubusercontent.com/f258008-art/EmotionDetection/main/kaggle%20(1).json'
response = requests.get(url)
data = response.json()
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'username': 'ridamohsin', 'key': 'ae0ea98249f951714b5269f517eece32'}

# %%
import pandas as pd
dataset_url = 'https://raw.githubusercontent.com/f258008-art/EmotionDetection/refs/heads/main/emotions-dataset.csv'
labels_url = 'https://raw.githubusercontent.com/f258008-art/EmotionDetection/refs/heads/main/emotion_labels.csv'
dataset_df=pd.read_csv(dataset_url)
labels_df=pd.read_csv(labels_url)
print(dataset_df.head())
print(labels_df.head())
df = pd.concat([dataset_df, labels_df['emotion']], axis=1)
print(df.head())
print(df['emotion'].value_counts())
print(df.columns)
# Out:
#                                              content  sentiment
# 0                   not a very good day at the house          1
# 1  tommcfly i saw you on tues and last niiiighht ...          2
# 2     i dont even understand the intro to this book           3
# 3      happy mothers day mommy and grandma haha  ily          0
# 4  quotoh i got so fucked up last nightquot but u...          3
#    label  emotion
# 0      0      Joy
# 1      1  Sadness
# 2      2  Neutral
# 3      3    Anger
#                                              content  sentiment  emotion
# 0                   not a very good day at the house          1      Joy
# 1  tommcfly i saw you on tues and last niiiighht ...          2  Sadness
# 2     i dont even understand the intro to this book           3  Neutral
# 3      happy mothers day mommy and grandma haha  ily          0    Anger
# 4  quotoh i got so fucked up last nightquot but u...          3      NaN
# emotion
# Joy        1
# Sadness    1
# ...

# %%
from transformers import BertTokenizer
import torch
from torch.utils.data import Dataset, DataLoader
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
label_map= {label: idx for idx, label in enumerate(df['emotion'].unique())}
df['labels'] = df['emotion'].map(label_map)
print(label_map)
print(label_map)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# {'Joy': 0, 'Sadness': 1, 'Neutral': 2, 'Anger': 3, nan: 4}
# {'Joy': 0, 'Sadness': 1, 'Neutral': 2, 'Anger': 3, nan: 4}

# %%
from transformers import BertTokenizer
from torch.utils.data import Dataset

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
max_len = 128

class EmotionDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f25533db-6b19-44fa-b8d5-9b7a9693cba9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f25533db-6b19-44fa-b8d5-9b7a9693cba9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'emotions-dataset.csv',
#  'emotions-dataset (1).csv',
#  'emotion_labels.csv',
#  'emotion-bert',
#  'sample_data']

# %%
import pandas as pd
df = pd.read_csv('emotions-dataset (1).csv')
df.head()
# Out:
#                                              content  sentiment
# 0                   not a very good day at the house          1
# 1  tommcfly i saw you on tues and last niiiighht ...          2
# 2     i dont even understand the intro to this book           3
# 3      happy mothers day mommy and grandma haha  ily          0
# 4  quotoh i got so fucked up last nightquot but u...          3

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
label_encoder = LabelEncoder()
df['encoded_labels'] = label_encoder.fit_transform(df['sentiment'])
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['content'].tolist(),
    df['encoded_labels'].tolist(),
    test_size=0.2,
    random_state=42
)

print("Train size:", len(train_texts))
print("Validation size:", len(val_texts))
# Out:
# Train size: 17640
# Validation size: 4410

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
max_len = 64

class EmotionDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            truncation=True,
            padding='max_length',
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %%
batch_size = 16

train_dataset = EmotionDataset(train_texts, train_labels, tokenizer, max_len)
val_dataset = EmotionDataset(val_texts, val_labels, tokenizer, max_len)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# %%
from transformers import BertForSequenceClassification
from torch.optim import AdamW
num_labels = len(df['encoded_labels'].unique())
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=num_labels)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
optimizer = AdamW(model.parameters(), lr=2e-5)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from tqdm import tqdm

def train_epoch(model, data_loader, optimizer, device):
    model.train()
    total_loss = 0
    for batch in tqdm(data_loader, desc="Training"):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels
        )

        loss = outputs.loss
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

    avg_loss = total_loss / len(data_loader)
    return avg_loss


def eval_epoch(model, data_loader, device):
    model.eval()
    total_loss = 0
    correct_preds = 0
    total_preds = 0

    with torch.no_grad():
        for batch in tqdm(data_loader, desc="Validating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels
            )

            loss = outputs.loss
            total_loss += loss.item()

            preds = torch.argmax(outputs.logits, dim=1)
            correct_preds += (preds == labels).sum().item()
            total_preds += labels.size(0)

    avg_loss = total_loss / len(data_loader)
    accuracy = correct_preds / total_preds
    return avg_loss, accuracy

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import numpy as np

def compute_metrics(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    acc = accuracy_score(labels_flat, preds_flat)
    f1 = f1_score(labels_flat, preds_flat, average='weighted')
    cm = confusion_matrix(labels_flat, preds_flat)
    return acc, f1, cm

# %%
epochs = 3

for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    train_loss = train_epoch(model, train_loader, optimizer, device)
    val_loss, val_acc = eval_epoch(model, val_loader, device)

    print(f"Train Loss: {train_loss:.4f}")
    print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")
# Out:
# Epoch 1/3
# ...
# Validating: 100%|██████████| 276/276 [15:25<00:00,  3.35s/it]
# Train Loss: 0.9287
# Validation Loss: 0.8230, Validation Accuracy: 0.6590
# Epoch 2/3
# ...
# Validating: 100%|██████████| 276/276 [15:09<00:00,  3.29s/it]
# Train Loss: 0.7062
# Validation Loss: 0.8390, Validation Accuracy: 0.6662
# Epoch 3/3
# Training:   0%|          | 1/1103 [00:22<7:00:49, 22.91s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3586505361.py in <cell line: 0>()
#       3 for epoch in range(epochs):
#       4     print(f"Epoch {epoch + 1}/{epochs}")
# ----> 5     train_loss = train_epoch(model, train_loader, optimizer, device)
#       6     val_loss, val_acc = eval_epoch(model, val_loader, device)
#       7
#
# /tmp/ipython-input-133956167.py in train_epoch(model, data_loader, optimizer, device)
#      18         loss = outputs.loss
# ...

# %%
import os, joblib

save_path = "emotion-bert"
if not os.path.exists(save_path):
    os.makedirs(save_path)
try:
    model.save_pretrained(save_path)
    tokenizer.save_pretrained(save_path)
    print("Model and tokenizer saved to", save_path)
except Exception as e:
    print("Error saving model/tokenizer:", e)
# Out:
# Model and tokenizer saved to emotion-bert

# %%
import os

save_path = "emotion-bert"
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
model.save_pretrained('emotion_model')
tokenizer.save_pretrained('emotion_model')
print("Model and tokenizer saved successfully!")
# Out:
# Model and tokenizer saved successfully!

# %%
le_save_path = os.path.join(save_path, "label_encoder.pkl")
try:
    joblib.dump(label_encoder, le_save_path)
    print("Label encoder saved to", le_save_path)
except NameError:
    print("label_encoder not found in memory. Recreating from data...")
    import pandas as pd
    df = pd.read_csv('emotions-dataset (1).csv')
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    try:
        le.fit(df['sentiment'])
        joblib.dump(le, le_save_path)
        print("Recreated and saved label encoder to", le_save_path)
    except Exception as e:
        print("Could not recreate label encoder automatically. Error:", e)
        print("You may need to create label_encoder manually and then run joblib.dump(label_encoder, path).")
# Out:
# Label encoder saved to emotion-bert/label_encoder.pkl

# %%
# !ls -lah emotion-bert
# Out:
# total 418M
# drwxr-xr-x 2 root root 4.0K Oct 28 16:55 .
# drwxr-xr-x 1 root root 4.0K Oct 28 16:55 ..
# -rw-r--r-- 1 root root  873 Oct 28 16:54 config.json
# -rw-r--r-- 1 root root  359 Oct 28 16:55 label_encoder.pkl
# -rw-r--r-- 1 root root 418M Oct 28 16:54 model.safetensors
# -rw-r--r-- 1 root root  125 Oct 28 16:54 special_tokens_map.json
# -rw-r--r-- 1 root root 1.3K Oct 28 16:54 tokenizer_config.json
# -rw-r--r-- 1 root root 227K Oct 28 16:54 vocab.txt

# %%
from shutil import make_archive
make_archive('emotion-bert', 'zip', 'emotion-bert')
from google.colab import files
files.download('emotion-bert.zip')

# %%
# !ls -lh emotion-bert.zip
# Out:
# -rw-r--r-- 1 root root 387M Oct 28 16:58 emotion-bert.zip

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import joblib
model = BertForSequenceClassification.from_pretrained('emotion-bert')
tokenizer = BertTokenizer.from_pretrained('emotion-bert')
label_encoder = joblib.load('emotion-bert/label_encoder.pkl')

# %%
pip install streamlit transformers torch joblib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 56.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 63.2 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
from transformers import BertTokenizer, BertForSequenceClassification
import torch
import joblib
# Set Streamlit page configuration
st.set_page_config(page_title="Emotion Detection", page_icon="😊", layout="centered")
@st.cache_resource
def load_model():
    model = BertForSequenceClassification.from_pretrained("emotion-bert")
    tokenizer = BertTokenizer.from_pretrained("emotion-bert")
    label_encoder = joblib.load("emotion-bert/label_encoder.pkl")
    return model, tokenizer, label_encoder

model, tokenizer, label_encoder = load_model()
st.title("Emotion Detection using BERT")
st.write("Enter a sentence below, and the model will predict the emotion it conveys.")
user_input = st.text_area("Enter your text here:", height=150)
if st.button("Detect Emotion"):
    if user_input.strip() == "":
        st.warning("Please enter some text.")
    else:
        inputs = tokenizer(
            user_input,
            return_tensors="pt",
            truncation=True,
            padding=True,
            max_length=128
        )
        model.eval()
        with torch.no_grad():
            outputs = model(**inputs)
            prediction = torch.argmax(outputs.logits, dim=1).item()
# Out:
# 2025-10-28 17:08:05.599 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 17:08:05.602 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 17:08:05.964
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-10-28 17:08:05.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 17:08:05.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 17:08:05.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !ls /content/emotion-bert
# Out:
# config.json	   model.safetensors	    tokenizer_config.json
# label_encoder.pkl  special_tokens_map.json  vocab.txt

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch, joblib
model = BertForSequenceClassification.from_pretrained("/content/emotion-bert")
tokenizer = BertTokenizer.from_pretrained("/content/emotion-bert")
label_encoder = joblib.load("/content/emotion-bert/label_encoder.pkl")
def predict_emotion(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
        pred = torch.argmax(outputs.logits, dim=1).item()
        emotion = label_encoder.inverse_transform([pred])[0]
    return emotion
examples = [
    "I am so happy today!",
    "This is terrible and I feel sad.",
    "I am angry about the delay!",
    "Nothing seems to matter anymore."
]

for text in examples:
    print(f"Text: {text}")
    print(f"Predicted Emotion: {predict_emotion(text)}\n")
# Out:
# Text: I am so happy today!
# Predicted Emotion: 2
#
# Text: This is terrible and I feel sad.
# Predicted Emotion: 1
#
# Text: I am angry about the delay!
# Predicted Emotion: 3
#
# Text: Nothing seems to matter anymore.
# Predicted Emotion: 1

# %%
import joblib
label_encoder = joblib.load("/content/emotion-bert/label_encoder.pkl")
print(label_encoder.classes_)
# Out:
# [0 1 2 3]

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch, joblib
model = BertForSequenceClassification.from_pretrained("/content/emotion-bert")
tokenizer = BertTokenizer.from_pretrained("/content/emotion-bert")
id2label = {
    0: "joy",
    1: "anger",
    2: "sadness",
    3: "fear",
    4: "love",
    5: "surprise"
}

def predict_emotion(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
        pred = torch.argmax(outputs.logits, dim=1).item()
        emotion = id2label.get(pred, "unknown")
    return emotion
examples = [
    "I am so happy today!",
    "This is terrible and I feel sad.",
    "I am angry about the delay!",
    "Nothing seems to matter anymore."
]

for text in examples:
    print(f"Text: {text}")
    print(f"Predicted Emotion: {predict_emotion(text)}\n")
# Out:
# Text: I am so happy today!
# Predicted Emotion: sadness
#
# Text: This is terrible and I feel sad.
# Predicted Emotion: anger
#
# Text: I am angry about the delay!
# Predicted Emotion: fear
#
# Text: Nothing seems to matter anymore.
# Predicted Emotion: anger

# %%
import pandas as pd
pd.read_csv("emotion_labels.csv").head()
# Out:
#    label  emotion
# 0      0      Joy
# 1      1  Sadness
# 2      2  Neutral
# 3      3    Anger

# %%
id2label = {
    0: "Neutral",
    1: "Joy",
    2: "Sadness",
    3: "Anger"
}

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch
model = BertForSequenceClassification.from_pretrained("/content/emotion-bert")
tokenizer = BertTokenizer.from_pretrained("/content/emotion-bert")
id2label = {
    0: "Joy",
    1: "Sadness",
    2: "Neutral",
    3: "Anger"
}
def predict_emotion(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
        pred = torch.argmax(outputs.logits, dim=1).item()
        emotion = id2label.get(pred, "Unknown")
    return emotion
examples = [
    "I am so happy today!",
    "This is terrible and I feel sad.",
    "I'm feeling calm and okay.",
    "I am angry about the delay!"
]

for text in examples:
    print(f"Text: {text}")
    print(f"Predicted Emotion: {predict_emotion(text)}\n")
# Out:
# Text: I am so happy today!
# Predicted Emotion: Neutral
#
# Text: This is terrible and I feel sad.
# Predicted Emotion: Sadness
#
# Text: I'm feeling calm and okay.
# Predicted Emotion: Sadness
#
# Text: I am angry about the delay!
# Predicted Emotion: Anger

# %%
# !pwd
# !ls
# Out:
# /content
#  emotion-bert	      emotion_model		  sample_data
#  emotion-bert.zip    'emotions-dataset (1).csv'
#  emotion_labels.csv   emotions-dataset.csv

# %%
# %cd /content/emotion-bert
# !ls
# Out:
# /content/emotion-bert
# config.json	   model.safetensors	    tokenizer_config.json
# label_encoder.pkl  special_tokens_map.json  vocab.txt

# %%
import joblib

encoder = joblib.load("label_encoder.pkl")
print("Encoder classes:", encoder.classes_)
# Out:
# Encoder classes: [0 1 2 3]

# %%
label_to_emotion = {
    0: "Joy",
    1: "Sadness",
    2: "Neutral",
    3: "Anger"
}

# %%
texts = [
    "I am so happy today!",
    "This is terrible and I feel sad.",
    "I'm feeling calm and okay.",
    "I am angry about the delay!"
]

for text in texts:
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    outputs = model(**inputs)
    predicted_label = outputs.logits.argmax().item()
    predicted_emotion = label_to_emotion.get(predicted_label, "Unknown")
    print(f"Text: {text}\nPredicted Emotion: {predicted_emotion}\n")
# Out:
# Text: I am so happy today!
# Predicted Emotion: Neutral
#
# Text: This is terrible and I feel sad.
# Predicted Emotion: Sadness
#
# Text: I'm feeling calm and okay.
# Predicted Emotion: Sadness
#
# Text: I am angry about the delay!
# Predicted Emotion: Anger

# %%
import joblib
encoder = joblib.load("label_encoder.pkl")
print("Encoder classes:", encoder.classes_)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3201937196.py in <cell line: 0>()
#       1 import joblib
# ----> 2 encoder = joblib.load("label_encoder.pkl")
#       3 print("Encoder classes:", encoder.classes_)
#
# /usr/local/lib/python3.12/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode, ensure_native_byte_order)
#     733             obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734     else:
# --> 735         with open(filename, "rb") as f:
#     736             with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737                 fobj,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'label_encoder.pkl'
